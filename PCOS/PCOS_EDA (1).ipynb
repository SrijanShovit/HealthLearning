# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sea

# %%
#load the dataset
#Dataset source - https://www.kaggle.com/datasets/shreyasvedpathak/pcos-dataset
#Read the dataset in pcos varaible

pcos = pd.read_csv('PCOS_data.csv')
pcos
# Out:
#      Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 0         1                 1           0          28         44.6
# 1         2                 2           0          36         65.0
# 2         3                 3           1          33         68.8
# 3         4                 4           0          37         65.0
# 4         5                 5           0          25         52.0
# ..      ...               ...         ...         ...          ...
# 536     537               537           0          35         50.0
# 537     538               538           0          30         63.2
# 538     539               539           0          36         54.0
# 539     540               540           0          27         50.0
# 540     541               541           1          23         82.0
#
#      Height(Cm)    BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0        152.000  19.3           15                78                22  ...
# ...

# %%
pcos.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#     BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0  19.3           15                78                22  ...
# 1  24.9           15                74                20  ...
# 2  25.3           11                72                18  ...
# 3  29.7           13                72                20  ...
# 4  20.1           11                72                18  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# 0              1.0                  0                  110
# ...

# %%
pcos.shape
# Out:
# (541, 45)

# %%
pcos.dtypes
# Out:
# Sl. No                      int64
# Patient File No.            int64
# PCOS (Y/N)                  int64
#  Age (yrs)                  int64
# Weight (Kg)               float64
# Height(Cm)                float64
# BMI                       float64
# Blood Group                 int64
# Pulse rate(bpm)             int64
# RR (breaths/min)            int64
# Hb(g/dl)                  float64
# Cycle(R/I)                  int64
# Cycle length(days)          int64
# Marraige Status (Yrs)     float64
# Pregnant(Y/N)               int64
# No. of abortions            int64
#   I   beta-HCG(mIU/mL)    float64
# II    beta-HCG(mIU/mL)     object
# FSH(mIU/mL)               float64
# LH(mIU/mL)                float64
# FSH/LH                    float64
# Hip(inch)                   int64
# Waist(inch)                 int64
# Waist:Hip Ratio           float64
# TSH (mIU/L)               float64
# AMH(ng/mL)                 object
# PRL(ng/mL)                float64
# ...

# %% [markdown]
# # Data cleaning

# %%
pcos.describe()
# Out:
#            Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# count  541.000000        541.000000  541.000000  541.000000   541.000000
# mean   271.000000        271.000000    0.327172   31.430684    59.637153
# std    156.317519        156.317519    0.469615    5.411006    11.028287
# min      1.000000          1.000000    0.000000   20.000000    31.000000
# 25%    136.000000        136.000000    0.000000   28.000000    52.000000
# 50%    271.000000        271.000000    0.000000   31.000000    59.000000
# 75%    406.000000        406.000000    1.000000   35.000000    65.000000
# max    541.000000        541.000000    1.000000   48.000000   108.000000
#
#        Height(Cm)          BMI  Blood Group  Pulse rate(bpm)   \
# count   541.000000  541.000000   541.000000        541.000000
# mean    156.484835   24.307579    13.802218         73.247689
# std       6.033545    4.055129     1.840812          4.430285
# ...

# %%
# missing values in dataframe

pcos.isnull().sum()
# Out:
# Sl. No                      0
# Patient File No.            0
# PCOS (Y/N)                  0
#  Age (yrs)                  0
# Weight (Kg)                 0
# Height(Cm)                  0
# BMI                         0
# Blood Group                 0
# Pulse rate(bpm)             0
# RR (breaths/min)            0
# Hb(g/dl)                    0
# Cycle(R/I)                  0
# Cycle length(days)          0
# Marraige Status (Yrs)       1
# Pregnant(Y/N)               0
# No. of abortions            0
#   I   beta-HCG(mIU/mL)      0
# II    beta-HCG(mIU/mL)      0
# FSH(mIU/mL)                 0
# LH(mIU/mL)                  0
# FSH/LH                      0
# Hip(inch)                   0
# Waist(inch)                 0
# Waist:Hip Ratio             0
# TSH (mIU/L)                 0
# AMH(ng/mL)                  0
# PRL(ng/mL)                  0
# Vit D3 (ng/mL)              0
# PRG(ng/mL)                  0
# RBS(mg/dl)                  0
# Weight gain(Y/N)            0
# ...

# %% [markdown]
# Here we found that there is very less number of null values.

# %%
# Identifying the columns having missing values

[features for features in pcos.columns if pcos[features].isnull().sum()>0]
# Out:
# ['Marraige Status (Yrs)', 'Fast food (Y/N)', 'Unnamed: 44']

# %%
# drop null values 

pcos.dropna(inplace = True)

# %%
pcos.isnull().sum()
# Out:
# Sl. No                    0
# Patient File No.          0
# PCOS (Y/N)                0
#  Age (yrs)                0
# Weight (Kg)               0
# Height(Cm)                0
# BMI                       0
# Blood Group               0
# Pulse rate(bpm)           0
# RR (breaths/min)          0
# Hb(g/dl)                  0
# Cycle(R/I)                0
# Cycle length(days)        0
# Marraige Status (Yrs)     0
# Pregnant(Y/N)             0
# No. of abortions          0
#   I   beta-HCG(mIU/mL)    0
# II    beta-HCG(mIU/mL)    0
# FSH(mIU/mL)               0
# LH(mIU/mL)                0
# FSH/LH                    0
# Hip(inch)                 0
# Waist(inch)               0
# Waist:Hip Ratio           0
# TSH (mIU/L)               0
# AMH(ng/mL)                0
# PRL(ng/mL)                0
# Vit D3 (ng/mL)            0
# PRG(ng/mL)                0
# RBS(mg/dl)                0
# Weight gain(Y/N)          0
# hair growth(Y/N)          0
# Skin darkening (Y/N)      0
# ...

# %% [markdown]
# Here we successfully remove the null values from the dataframe.

# %%
 # removing unrelated/blank columns
    
pcos.drop('Unnamed: 44', axis = 1, inplace = True)

# %%
# column AMH(ng/mL) have decimal vallues but it has type object
# we have to convert this columns data type into float64

pcos['AMH(ng/mL)']
# Out:
# 0      2.07
# 1      1.53
# 2      6.63
# 3      1.22
# 4      2.26
#        ...
# 536     1.7
# 537     5.6
# 538     3.7
# 539     5.2
# 540      20
# Name: AMH(ng/mL), Length: 541, dtype: object

# %%
# column 'II    beta-HCG(mIU/mL)' have decimal vallues but it has type object
# we have to convert this columns data type into float64
pcos['II    beta-HCG(mIU/mL)']
# Out:
# 0        1.99
# 1        1.99
# 2      494.08
# 3        1.99
# 4      801.45
#         ...
# 536      1.99
# 537      1.99
# 538      1.99
# 539      1.99
# 540      1.99
# Name: II    beta-HCG(mIU/mL), Length: 539, dtype: object

# %% [markdown]
# Here the column name "II    beta-HCG(mIU/mL)" have float values but its data type is object. So, we have to change its data type into float. In this column there is a value having string type which cannot be converted into float64. So, we create a function to convert the datatype if we found some ValueError then it return 'NaN' value.

# %%
# Function to convert values to float

def to_float(value):
    try:
        return float(value)
    except ValueError:
        return np.nan

# %%
# Change data type

pcos['II    beta-HCG(mIU/mL)'] = pcos['II    beta-HCG(mIU/mL)'].apply(to_float)
pcos['II    beta-HCG(mIU/mL)'] = pcos['II    beta-HCG(mIU/mL)'].astype('float64')

pcos['AMH(ng/mL)'] = pcos['AMH(ng/mL)'].apply(to_float)
pcos['AMH(ng/mL)'] = pcos['AMH(ng/mL)'].astype('float64')

# %%
pcos.isnull().sum()
# Out:
# PCOS (Y/N)                0
#  Age (yrs)                0
# Weight (Kg)               0
# Height(Cm)                0
# BMI                       0
# Blood Group               0
# Pulse rate(bpm)           0
# RR (breaths/min)          0
# Hb(g/dl)                  0
# Cycle(R/I)                0
# Cycle length(days)        0
# Marraige Status (Yrs)     0
# Pregnant(Y/N)             0
# No. of abortions          0
#   I   beta-HCG(mIU/mL)    0
# II    beta-HCG(mIU/mL)    0
# FSH(mIU/mL)               0
# LH(mIU/mL)                0
# FSH/LH                    0
# Hip(inch)                 0
# Waist(inch)               0
# Waist:Hip Ratio           0
# TSH (mIU/L)               0
# AMH(ng/mL)                1
# PRL(ng/mL)                0
# Vit D3 (ng/mL)            0
# PRG(ng/mL)                0
# RBS(mg/dl)                0
# Weight gain(Y/N)          0
# hair growth(Y/N)          0
# Skin darkening (Y/N)      0
# Hair loss(Y/N)            0
# Pimples(Y/N)              0
# ...

# %%
pcos.dropna(inplace = True)

# %%
pcos.isnull().sum()
# Out:
# Sl. No                    0
# Patient File No.          0
# PCOS (Y/N)                0
#  Age (yrs)                0
# Weight (Kg)               0
# Height(Cm)                0
# BMI                       0
# Blood Group               0
# Pulse rate(bpm)           0
# RR (breaths/min)          0
# Hb(g/dl)                  0
# Cycle(R/I)                0
# Cycle length(days)        0
# Marraige Status (Yrs)     0
# Pregnant(Y/N)             0
# No. of abortions          0
#   I   beta-HCG(mIU/mL)    0
# II    beta-HCG(mIU/mL)    0
# FSH(mIU/mL)               0
# LH(mIU/mL)                0
# FSH/LH                    0
# Hip(inch)                 0
# Waist(inch)               0
# Waist:Hip Ratio           0
# TSH (mIU/L)               0
# AMH(ng/mL)                0
# PRL(ng/mL)                0
# Vit D3 (ng/mL)            0
# PRG(ng/mL)                0
# RBS(mg/dl)                0
# Weight gain(Y/N)          0
# hair growth(Y/N)          0
# Skin darkening (Y/N)      0
# ...

# %%
# make the sl. No index and remove the sl. No. column from the data frame 

pcos.index = pcos['Sl. No']

del(pcos['Sl. No'])

# %%
del(pcos['Patient File No.'])

# %% [markdown]
# Now we successfully convert the datatype and also handle the missing values.

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Select numerical variables
numerical_vars = pcos.select_dtypes(include=['float64', 'int64']).columns

# Calculate summary statistics for numerical variables
summary_stats = pcos[numerical_vars].agg(['mean', 'median', 'std', 'min', 'max'])

# Display the summary statistics
print(summary_stats)
# Out:
#         PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)         BMI  \
# mean      0.325885   31.435754    59.680633   156.492171  24.324022
# median    0.000000   31.000000    59.600000   156.000000  24.200000
# std       0.469141    5.406608    11.028685     6.041379   4.058256
# min       0.000000   20.000000    31.000000   137.000000  12.400000
# max       1.000000   48.000000   108.000000   180.000000  38.900000
#
#         Blood Group  Pulse rate(bpm)   RR (breaths/min)   Hb(g/dl)  \
# mean      13.800745         73.249534         19.238361  11.161229
# median    14.000000         72.000000         18.000000  11.000000
# std        1.845567          4.445894          1.689238   0.869186
# min       11.000000         13.000000         16.000000   8.500000
# max       18.000000         82.000000         28.000000  14.800000
#
#         Cycle(R/I)  ...  Pimples(Y/N)  Fast food (Y/N)  Reg.Exercise(Y/N)  \
# mean      2.556797  ...      0.491620         0.515829           0.243948
# ...

# %%
# List of the columns in dataframe

for col in pcos.columns :
    print(col)
# Out:
# PCOS (Y/N)
#  Age (yrs)
# Weight (Kg)
# Height(Cm)
# BMI
# Blood Group
# Pulse rate(bpm)
# RR (breaths/min)
# Hb(g/dl)
# Cycle(R/I)
# Cycle length(days)
# Marraige Status (Yrs)
# Pregnant(Y/N)
# No. of abortions
#   I   beta-HCG(mIU/mL)
# II    beta-HCG(mIU/mL)
# FSH(mIU/mL)
# LH(mIU/mL)
# FSH/LH
# Hip(inch)
# Waist(inch)
# Waist:Hip Ratio
# TSH (mIU/L)
# AMH(ng/mL)
# PRL(ng/mL)
# Vit D3 (ng/mL)
# PRG(ng/mL)
# RBS(mg/dl)
# Weight gain(Y/N)
# hair growth(Y/N)
# Skin darkening (Y/N)
# Hair loss(Y/N)
# Pimples(Y/N)
# Fast food (Y/N)
# Reg.Exercise(Y/N)
# BP _Systolic (mmHg)
# BP _Diastolic (mmHg)
# Follicle No. (L)
# Follicle No. (R)
# Avg. F size (L) (mm)
# Avg. F size (R) (mm)
# Endometrium (mm)

# %% [markdown]
# # Here we segregate the target and features for further data processing and visualization.

# %%
# specifying target and features
target = 'PCOS (Y/N)'
all_features = list(pcos.columns[1:])
print('Target: ', target)
print('Features:', all_features)
# Out:
# Target:  PCOS (Y/N)
# Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of abortions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']

# %%
# creating referrences for features data, categorial and non-categorial features data
all_features = list(pcos.columns[1:])
features_df = pcos[all_features]
binary_features = features_df.columns[(features_df.max() == 1) & (features_df.min() == 0)]
print('binary features : ', binary_features)
binary_data = features_df[binary_features]

pcos.info()
# Out:
# binary features :  Index(['Pregnant(Y/N)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Fast food (Y/N)', 'Reg.Exercise(Y/N)'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 537 entries, 1 to 541
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PCOS (Y/N)              537 non-null    int64
#  1    Age (yrs)              537 non-null    int64
#  2   Weight (Kg)             537 non-null    float64
#  3   Height(Cm)              537 non-null    float64
#  4   BMI                     537 non-null    float64
#  5   Blood Group             537 non-null    int64
#  6   Pulse rate(bpm)         537 non-null    int64
#  7   RR (breaths/min)        537 non-null    int64
#  8   Hb(g/dl)                537 non-null    float64
#  9   Cycle(R/I)              537 non-null    int64
# ...

# %% [markdown]
# # Creating countplots on categorial features to determine their balance ratio in the features set.

# %%
# creating countplot for categorial features

def create_countplots(df, features, target) -> None:
    for feature in features:
        plt.figure(figsize=(5,5))
        sea.countplot(data=df, x=feature,hue=target)
        plt.xlabel(feature)
        plt.ylabel('Count')
        plt.legend()
        plt.title(f"Countplot for {feature}")
        plt.show()

        
create_countplots(pcos, binary_features, target)

# %%
ax = sea.countplot(x = "Marraige Status (Yrs)", data = pcos)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# Here a graph which shows the number of patients having differnt Marraige status (years). Marriage Status can be measured in years. Minimum value is 0.0 and maximum value is 30.0 .

# %% [markdown]
# Here is the graph showing how many patients are pregnant.

# %%
# plot the graph of age

ax = sea.countplot(data = pcos, x = ' Age (yrs)', hue = 'PCOS (Y/N)')


for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# Here the minimum age is 20 yrs and maximum age is 48 yrs. From the above graph we found that most of the patients are age group between 27-28.

# %%
# number of pateints having abortions more than 0.

ax = sea.countplot(data = pcos, x = 'No. of abortions')


for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plot the graph of blood group 

ax = sea.countplot(x = 'Blood Group', data = pcos)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Select numeric columns (integers and floats)
ax = pcos.select_dtypes([np.int64, np.float64])

num_cols = 3
num_rows = 14

# Create a new figure with subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize = (20,20))

# Create histograms for each symptom and place them in the grid
for i, col in enumerate(ax.columns):
    row_idx = i // num_cols
    col_idx = i % num_cols
    axes[row_idx, col_idx].hist(ax[col], bins=20)  # Adjust the number of bins as needed
    axes[row_idx, col_idx].set_title(f'Histogram for Symptom {col}')
    axes[row_idx, col_idx].set_xlabel('Value')
    axes[row_idx, col_idx].set_ylabel('Frequency')
    
plt.tight_layout()
plt.show()

# %%
# calculate the skewness for each column

def calculate_skewness_loop(pcos):
  """
  Calculates skewness of each numeric column in the dataframe using a loop.

  Args:
      df: A pandas dataframe.

  Returns:
      A dictionary containing column names as keys and skewness values.
  """
  skewness = {}
  for col in pcos.columns:
    if not pd.api.types.is_numeric_dtype(pcos[col]):
      continue
    skewness[col] = pcos[col].skew()
  return skewness

result = calculate_skewness_loop(pcos.copy())

print("Skewness of each column:")
for col, skew in result.items():
    print(f"Column: {col}, Skewness: {skew:.2f}")
# Out:
# Skewness of each column:
# Column: PCOS (Y/N), Skewness: 0.75
# Column:  Age (yrs), Skewness: 0.36
# Column: Weight (Kg), Skewness: 0.52
# Column: Height(Cm) , Skewness: 0.32
# Column: BMI, Skewness: 0.27
# Column: Blood Group, Skewness: -0.13
# Column: Pulse rate(bpm) , Skewness: -7.93
# Column: RR (breaths/min), Skewness: 1.24
# Column: Hb(g/dl), Skewness: 0.74
# Column: Cycle(R/I), Skewness: 1.01
# Column: Cycle length(days), Skewness: 0.83
# Column: Marraige Status (Yrs), Skewness: 1.14
# Column: Pregnant(Y/N), Skewness: 0.48
# Column: No. of abortions, Skewness: 2.96
# Column:   I   beta-HCG(mIU/mL), Skewness: 7.49
# Column: II    beta-HCG(mIU/mL), Skewness: 12.76
# Column: FSH(mIU/mL), Skewness: 23.16
# Column: LH(mIU/mL), Skewness: 23.15
# Column: FSH/LH, Skewness: 21.39
# Column: Hip(inch), Skewness: -0.21
# Column: Waist(inch), Skewness: 0.20
# Column: Waist:Hip Ratio, Skewness: -0.34
# Column: TSH (mIU/L), Skewness: 10.03
# Column: AMH(ng/mL), Skewness: 3.33
# ...

# %%
# multivariate analysis between weight and height
 
sea.scatterplot(x="Weight (Kg)", y="Height(Cm) ", data=pcos)
# Out:
# <Axes: xlabel='Weight (Kg)', ylabel='Height(Cm) '>

# %%
# multivariate analysis between   I   beta-HCG(mIU/mL) and II    beta-HCG(mIU/mL)
 
sea.scatterplot(x="  I   beta-HCG(mIU/mL)", y="II    beta-HCG(mIU/mL)", data=pcos)
# Out:
# <Axes: xlabel='  I   beta-HCG(mIU/mL)', ylabel='II    beta-HCG(mIU/mL)'>

# %% [markdown]
# # Forming a correlation matrix between the features and target.

# %%
# correlation  matrix
plt.figure(figsize = (10,8))
sea.set(font_scale=0.6)
corr = pcos.corr()
sea.heatmap(corr)
# Out:
# <Axes: >

# %%
# correlation matrix
corr_matrix = pcos.corr().abs()
corr_matrix[target].sort_values()
# Out:
# PRL(ng/mL)                0.003294
# TSH (mIU/L)               0.004373
# Waist:Hip Ratio           0.012919
# II    beta-HCG(mIU/mL)    0.013228
# BP _Systolic (mmHg)       0.013286
# FSH/LH                    0.018286
# Pregnant(Y/N)             0.025592
#   I   beta-HCG(mIU/mL)    0.027598
# FSH(mIU/mL)               0.030324
# Blood Group               0.032041
# BP _Diastolic (mmHg)      0.037020
# RR (breaths/min)          0.040696
# PRG(ng/mL)                0.044204
# RBS(mg/dl)                0.050688
# No. of abortions          0.056317
# LH(mIU/mL)                0.064239
# Reg.Exercise(Y/N)         0.067619
# Height(Cm)                0.068536
# Vit D3 (ng/mL)            0.086195
# Hb(g/dl)                  0.089103
# Pulse rate(bpm)           0.092428
# Avg. F size (R) (mm)      0.093478
# Endometrium (mm)          0.103203
# Marraige Status (Yrs)     0.110604
# Avg. F size (L) (mm)      0.128089
# Hip(inch)                 0.156394
# Waist(inch)               0.159339
# ...

# %%
#calculate correlation from different methods


# Calculate Pearson's correlation
corr_pearson = pcos.corr()

# Calculate Spearman's rank correlation
corr_spearman = pcos.corr(method='spearman')

# Calculate Kendall's rank correlation
corr_kendall = pcos.corr(method='kendall')

plt.figure(figsize = (25,15))

# Print the different correlation matrices
print("Pearson's correlation:")
sea.heatmap(corr_pearson)

print("Spearman's rank correlation: ")
sea.heatmap(corr_spearman)

print("Kendall's rank correlation:")
sea.heatmap(corr_kendall)
# Out:
# Pearson's correlation:
# Spearman's rank correlation:
# Kendall's rank correlation:
# <Axes: >

# %% [markdown]
# # Visualizing the top 17 features with highest correlation with a correlation heatmap.

# %%
plt.figure(figsize=(10,8))
sea.set(font_scale=0.6)
indexes = corr_matrix.nlargest(17, target)[target].index
cm = pd.DataFrame(np.corrcoef(pcos[indexes].values.T))
sea.heatmap(data = cm, annot = True, yticklabels = indexes.values,
            xticklabels = indexes.values, cbar =True, cmap = 'YlGnBu',
            square = True)
plt.title(f"correlation heatmap with {target}")
plt.show()

# %% [markdown]
# # Filtering out features with over 80% mutual correlation factor for identification.

# %%
correlation_threshold = 0.8 # threshold = 80%
upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
highly_correlated_pairs = []

# Iterate through the DataFrame and find highly correlated feature pairs
for column in upper_triangle.columns:
    correlated_columns = upper_triangle.index[upper_triangle[column] >= correlation_threshold].tolist()
    for correlated_column in correlated_columns:
        pair = (column, correlated_column)
        highly_correlated_pairs.append(pair)
highly_correlated_pairs
# Out:
# [('BMI', 'Weight (Kg)'),
#  ('FSH/LH', 'FSH(mIU/mL)'),
#  ('Waist(inch)', 'Hip(inch)'),
#  ('Follicle No. (R)', 'Follicle No. (L)')]

# %% [markdown]
# # Detecting Outliers From Features
# There are outliers present in the dataset. Distance -based models such as K-Nearest-Neighbours classifieres are particularly sensitive to outliers as they cluster the data into classes based on their proximity with other data points,
# and hence their presence can distort the model's results.
# Also, models trained on datasets containing outliers may not generalize well to new, unseen data.
# Hence, removing those outliers is necessary for optimal performance.

# %%
# box to visualize outliers
all_features = list(pcos.columns[1:])
features_df = pcos[all_features]
binary_features = features_df.columns[(features_df.max() == 1) & (features_df.min() == 0)]
nonbinary_data = features_df.drop(binary_features, axis=1)
for feature in nonbinary_data.columns.to_list():
  plt.figure(figsize=(5,3))
  sea.boxplot(data=pcos, x=target, y=feature, hue = target)
  plt.xlabel(target)
  plt.ylabel(feature)
  plt.title(f"Boxplot for {feature}")
  plt.show()
